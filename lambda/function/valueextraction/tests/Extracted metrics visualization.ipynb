# %% [markdown]
# # Extracted metrics visualization

# %%
import pandas as pd

# %%
extracted_metrics = pd.read_csv("output_data/extracted_metrics.tsv",
                               sep = ";")
extracted_metrics.head()
# Out:
#                                    uuid  \
# 0  75e5d630-c43d-4d57-a2c7-381cdede7bf1
# 1  75e5d630-c43d-4d57-a2c7-381cdede7bf1
# 2  75e5d630-c43d-4d57-a2c7-381cdede7bf1
# 3  75e5d630-c43d-4d57-a2c7-381cdede7bf1
# 4  75e5d630-c43d-4d57-a2c7-381cdede7bf1
#
#                                                 text surface  value      unit  \
# 0  EU Official Journal Publication: 2019/S 243-59...  4.0 MW    4.0  megawatt
# 1  EU Official Journal Publication: 2019/S 243-59...  1.0 MW    1.0  megawatt
# 2  EU Official Journal Publication: 2019/S 243-59...  5.0 MW    5.0  megawatt
# 3  EU Official Journal Publication: 2019/S 243-59...  1.2 MW    1.2  megawatt
# 4  EU Official Journal Publication: 2019/S 243-59...  1.0 MW    1.0  megawatt
#
#   entity to_official_unit  is_title  is_desc
# 0  power     4000000.00 W         0        1
# 1  power     1000000.00 W         0        1
# 2  power     5000000.00 W         0        1
# 3  power     1200000.00 W         0        1
# 4  power     1000000.00 W         0        1

# %%
# Number of values
extracted_metrics.shape
# Out:
# (11, 9)

# %%
extracted_metrics
# Out:
#                                     uuid  \
# 0   75e5d630-c43d-4d57-a2c7-381cdede7bf1
# 1   75e5d630-c43d-4d57-a2c7-381cdede7bf1
# 2   75e5d630-c43d-4d57-a2c7-381cdede7bf1
# 3   75e5d630-c43d-4d57-a2c7-381cdede7bf1
# 4   75e5d630-c43d-4d57-a2c7-381cdede7bf1
# 5   666d900f-dcb3-40a1-8d90-f338c7adb94b
# 6   666d900f-dcb3-40a1-8d90-f338c7adb94b
# 7   c0913ee3-bff5-474e-b199-c3b58f4323a2
# 8   c0913ee3-bff5-474e-b199-c3b58f4323a2
# 9   838f927b-e255-4df8-beea-9e895a188cba
# 10  03ba3287-d342-41f5-b702-f600bce0de7a
#
#                                                  text         surface  \
# 0   EU Official Journal Publication: 2019/S 243-59...          4.0 MW
# 1   EU Official Journal Publication: 2019/S 243-59...          1.0 MW
# 2   EU Official Journal Publication: 2019/S 243-59...          5.0 MW
# 3   EU Official Journal Publication: 2019/S 243-59...          1.2 MW
# 4   EU Official Journal Publication: 2019/S 243-59...          1.0 MW
# 5   Nederland-Delft: Aardolieproducten, brandstof,...  46 800 000 kWh
# 6   Nederland-Delft: Aardolieproducten, brandstof,...         2500 EH
# 7   Polska-Wałbrzych: Energia elektryczna, cieplna...   4 128 595 kWh
# 8   Polska-Wałbrzych: Energia elektryczna, cieplna...   4 747 884 kWh
# 9   Periodical Electrical Testing To Corporate Pro...     2020-2022 A
# 10  \n\n    CN ID:\n    \n        CN3658426\n    \...             14A
#
#          value           unit   entity   to_official_unit  is_title  is_desc
# 0          4.0       megawatt    power       4000000.00 W         0        1
# 1          1.0       megawatt    power       1000000.00 W         0        1
# 2          5.0       megawatt    power       5000000.00 W         0        1
# 3          1.2       megawatt    power       1200000.00 W         0        1
# 4          1.0       megawatt    power       1000000.00 W         0        1
# 5   46800000.0  kilowatt hour   energy  46800000000.00 Wh         0        1
# 6       2500.0        hartree   energy            0.00 Wh         0        1
# 7    4128595.0  kilowatt hour   energy   4128595000.00 Wh         0        1
# 8    4747884.0  kilowatt hour   energy   4747884000.00 Wh         0        1
# 9       4042.0         ampere  current          4042.00 A         0        1
# 10        14.0         ampere  current            14.00 A         0        1

# %% [markdown]
# A la ligne 5 on peut voir que le programme gère mal les intervalles de valeur. Également, il n'y a que 7 valeurs et c'est très curieux
